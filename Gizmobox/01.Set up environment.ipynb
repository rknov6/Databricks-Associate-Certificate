-- %%
%python
%fs ls abfss://gizmobox@stgdeltadatabricks.dfs.core.windows.net/landing/operational/customers/

-- %% [markdown]
-- #### Create external location

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS gizmobox
    URL "abfss://gizmobox@stgdeltadatabricks.dfs.core.windows.net/"
    WITH (STORAGE CREDENTIAL `databricks-sc`)

-- %% [markdown]
-- #### Create catalog

-- %%
CREATE CATALOG IF NOT EXISTS gizmobox
   MANAGED LOCATION 'abfss://gizmobox@stgdeltadatabricks.dfs.core.windows.net/'

-- %%
select current_catalog();

-- %%
use catalog gizmobox

-- %% [markdown]
-- #### create schemas

-- %%
CREATE SCHEMA IF NOT EXISTS gizmobox.landing
    MANAGED LOCATION 'abfss://gizmobox@stgdeltadatabricks.dfs.core.windows.net/landing/';
