-- %%
select * from csv.`abfss://gizmobox@stgdeltadatabricks.dfs.core.windows.net/landing/external/payments/`

-- %%
drop table if exists gizmobox.bronze.t_payments;
create table if not exists gizmobox.bronze.t_payments
(
  payment_id int,
  order_id int,
  payment_timestamp timestamp,
  payment_status int,
  payment_method string
)
using csv
options(header = "true")
location "abfss://gizmobox@stgdeltadatabricks.dfs.core.windows.net/landing/external/payments/"

-- %%
select * from gizmobox.bronze.t_payments
order by payment_id;

-- %%
describe extended gizmobox.bronze.t_payments

-- %%
select * from gizmobox.bronze.t_payments;

-- %%
refresh table gizmobox.bronze.t_payments

-- %%
drop table if exists gizmobox.bronze.t_payments;
