# %%
df = spark.read.option("header", 'false').csv("abfss://gizmobox@stgdeltadatabricks.dfs.core.windows.net/landing/external/payments")
df.display()

# %%
df = spark.sql('select * from csv.`abfss://gizmobox@stgdeltadatabricks.dfs.core.windows.net/landing/external/payments`')
df.display()

# %%
df = spark.table("gizmobox.bronze.t_payments")
df.display()
