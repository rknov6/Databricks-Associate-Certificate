-- %%
%python
df = spark.read.options(header = "true",sep = "\t").csv("/Volumes/gizmobox/landing/operational/addresses/")
df.display()

-- %%
%python
df = spark.read.option("header","true").option("sep","\t").csv("/Volumes/gizmobox/landing/operational/addresses/")
df.display()

-- %%
select * from read_files('/Volumes/gizmobox/landing/operational/addresses/', format => 'csv', header => true,delimiter => '\t')

-- %%
create or replace view gizmobox.bronze.addresses
as
select * from 
read_files('/Volumes/gizmobox/landing/operational/addresses/', format => 'csv', header => true,delimiter => '\t')

-- %%
select * from gizmobox.bronze.addresses
