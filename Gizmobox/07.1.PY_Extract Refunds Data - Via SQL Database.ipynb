# %%
df = spark.read.format("jdbc").options(url = "jdbc:sqlserver://gizmobox-server6.database.windows.net:1433;database=gizmobox-db",dbtable = 'refunds',user = 'gizmoboxadmin',password = 'krishna@89').load()
df.display()

# %%
df.writeTo("gizmobox.bronze.py_refunds").createOrReplace()

# %%
# %sql
select * from gizmobox.bronze.py_refunds
