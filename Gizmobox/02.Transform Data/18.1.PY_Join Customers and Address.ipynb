# %%
from pyspark.sql.functions import col

# %%
df_address = spark.table("gizmobox.silver.py_addresses")
df_customers = spark.table("gizmobox.silver.py_customers")

# %%
df_join = df_address.alias("a").join(df_customers.alias("c"),col("a.customer_id") == col("c.customer_id"),"inner") \
                     .select("c.customer_id","c.customer_name","c.date_of_birth","c.email","c.member_since","c.telephone","a.shipping_address_line_1","a.shipping_city","a.shipping_state","a.shipping_postcode","a.billing_address_line_1","a.billing_city","a.billing_state","a.billing_postcode")

# %%
df_join.writeTo("gizmobox.gold.py_customer_addresses").createOrReplace()
