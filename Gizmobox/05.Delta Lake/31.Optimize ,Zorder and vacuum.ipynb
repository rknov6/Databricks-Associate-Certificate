-- %%
create table demo.delta_lake.optimize_raw_stock_prices
(
  name string,
  founded_date date,
  location string
);

-- %%
insert into demo.delta_lake.optimize_raw_stock_prices values ('Microsoft',"1976-09-04","USA")

-- %%
insert into demo.delta_lake.optimize_raw_stock_prices values ('Google',"1998-09-04","USA")

-- %%
insert into demo.delta_lake.optimize_raw_stock_prices values ('Alibaba',"1999-09-04","China");

-- %%
insert into demo.delta_lake.optimize_raw_stock_prices values ('Apple',"1975-09-04","USA");

-- %%
desc history demo.delta_lake.optimize_raw_stock_prices

-- %%
select * from demo.delta_lake.optimize_raw_stock_prices

-- %%
optimize demo.delta_lake.optimize_raw_stock_prices

-- %%
optimize demo.delta_lake.optimize_raw_stock_prices
zorder by name;

-- %%
%python
spark.conf.set("spark.databricks.delta.retentionDurationCheck.enabled", "false")

-- %%
vacuum demo.delta_lake.optimize_raw_stock_prices retain 0 hours

-- %%
select * from demo.delta_lake.optimize_raw_stock_prices version as of 4
