# %%
df_json = spark.read.json("/Volumes/gizmobox/landing/operational/orders")
df_json.display()

# %%
df = spark.read.text("/Volumes/gizmobox/landing/operational/orders")
df.display()

# %%
df.writeTo("gizmobox.bronze.py_orders").createOrReplace()

# %%
spark.table("gizmobox.bronze.py_orders").display()
