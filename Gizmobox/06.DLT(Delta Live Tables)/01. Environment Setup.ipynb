-- %%
create catalog if not exists circuitbox
managed location 'abfss://circuitbox@stgdeltadatabricks.dfs.core.windows.net/'

-- %%
create schema circuitbox.landing
managed location 'abfss://circuitbox@stgdeltadatabricks.dfs.core.windows.net/landing'

-- %%
CREATE EXTERNAL VOLUME circuitbox.landing.operationaldata
LOCATION 'abfss://circuitbox@stgdeltadatabricks.dfs.core.windows.net/landing/operationaldata/';

-- %%
create schema circuitbox.lakehouse
managed location 'abfss://circuitbox@stgdeltadatabricks.dfs.core.windows.net/lakehouse'

-- %%
select * from json.`/Volumes/circuitbox/landing/operationaldata/customers/*.json`

-- %%
select * from circuitbox.lakehouse.silver_customers_clean;
