# %%
df = spark.read.format("binaryFile").load("/Volumes/gizmobox/landing/operational/memberships/*")
df.display()

# %%
df.writeTo("gizmobox.bronze.py_memberships").createOrReplace()

# %%
spark.sql("""
          select * from gizmobox.bronze.py_memberships
          """
          ).display()
