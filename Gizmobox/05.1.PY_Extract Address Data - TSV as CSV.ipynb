# %%
df = spark.read.options(header = "true",delimiter = "\t").csv("/Volumes/gizmobox/landing/operational/addresses")
df.display()

# %%
df.writeTo("gizmobox.bronze.py_addresses").createOrReplace()

# %%
# %sql
select * from gizmobox.bronze.py_addresses
